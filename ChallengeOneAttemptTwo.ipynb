# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as im

# %matplotlib inline 

gear_dir = "gear_images/gear_images"

images = {}; 

for folder in sorted(os.listdir(gear_dir)):
    folderPath = os.path.join(gear_dir, folder)
    print(folderPath, ':')
    for file in sorted(os.listdir(folderPath)):
        # print('\t', file)
        totalPath = os.path.join(gear_dir, folder, file)
        print(os.path.join(gear_dir, folder, file))
        # print(im.imread(totalPath).shape)
        images[totalPath] = im.imread(totalPath).shape
        # img = im.read(os.path.join(gear_dir, folderPath, file))
# Out:
# gear_images/gear_images/axes :
# gear_images/gear_images/axes/100172.jpeg
# gear_images/gear_images/axes/10036053x1012980_zm.jpeg
# gear_images/gear_images/axes/10045714_zm.jpeg
# gear_images/gear_images/axes/100937.jpeg
# gear_images/gear_images/axes/100938.jpeg
# gear_images/gear_images/axes/10101173x1012980_zm.jpeg
# gear_images/gear_images/axes/10188438x1011898_zm.jpeg
# gear_images/gear_images/axes/10189964_zm.jpeg
# gear_images/gear_images/axes/10189970_zm.jpeg
# gear_images/gear_images/axes/10189971_zm.jpeg
# gear_images/gear_images/axes/10215531x1028317_zm.jpeg
# gear_images/gear_images/axes/10258915x1152209_zm.jpeg
# gear_images/gear_images/axes/10260981_zm.jpeg
# gear_images/gear_images/axes/10260983_zm.jpeg
# gear_images/gear_images/axes/10285571x1013345_zm.jpeg
# gear_images/gear_images/axes/10285573x1013345_zm.jpeg
# gear_images/gear_images/axes/10291030_zm.jpeg
# gear_images/gear_images/axes/10291102_zm.jpeg
# gear_images/gear_images/axes/10321075_zm.jpeg
# ...

# %%
imageList = []; 
for folder in sorted(os.listdir(gear_dir)):
    folderPath = os.path.join(gear_dir, folder)
    for file in sorted(os.listdir(folderPath)):
        totalPath = os.path.join(gear_dir, folder, file)
        item = (file, totalPath, np.array(Image.open(totalPath)))
        imageList.insert(0, (file, totalPath, np.array(Image.open(totalPath)), folder))

# %%
print (imageList[0])
# Out:
# ('PAAAAALKBOLDLPOPx1013041_zm.jpeg', 'gear_images/gear_images/tents/PAAAAALKBOLDLPOPx1013041_zm.jpeg', array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
homedir = os.path.expanduser('~')
pathset = os.path.join(homedir, "notebooks/ProcessingTemp")
print(pathset)

if not(os.path.exists(pathset)):
    print ("NEW DIRECTORY COOL")
    os.mkdir(pathset)
# Out:
# /home/conductor/notebooks/ProcessingTemp

# %%
someImages = imageList[0:5]

# %%
for x in someImages:
    output_filename = x[0]
    np.save(os.path.join(pathset, output_filename), x[2])

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
# %matplotlib inline

# Show the original and resized images
# Create a figure
fig = plt.figure(figsize=(12, 12))


orig_img = Image.fromarray(someImages[0][2])

#imgJpeg = Image.open('gear_images/gear_images/boots/PAAAIALEPOLAOKBAx1039826_zm.jpeg')
#imgJpeg = Image.open(someImages[0][1])
#print(someImages[0][1])
#imgAsArray = np.array(imgJpeg)
#orig_img = Image.fromarray(someImages[0][2])

# Get the image size
orig_height, orig_width = orig_img.size
print('Original size:', orig_height, 'x', orig_width)

# Subplot for original image
a=fig.add_subplot(211)
imgplot = plt.imshow(orig_img)
a.set_title('Original')


# We'll resize this so it's 200 x 200
target_size = (128,128)
#target_size = (308,354)


# Scale the image to the new size using the thumbnail method
scaled_img = orig_img
scaled_img.thumbnail(target_size, Image.ANTIALIAS)
scaled_height, scaled_width = scaled_img.size
print('Scaled size:', scaled_height, 'x', scaled_width)

# Create a new white image of the target size to be the background
new_img = Image.new("RGB", target_size, (0, 0, 255))

# paste the scaled image into the center of the white background image
new_img.paste(scaled_img, (int((target_size[0] - scaled_img.size[0]) / 2), int((target_size[1] - scaled_img.size[1]) / 2)))
new_height, new_width = new_img.size
print('New size:', new_height, 'x', new_width)



# Subplot for scaled image
#a=fig.add_subplot(312)
#imgplot = plt.imshow(scaled_img)
#a.set_title('Scaled')

# Subplot for resized image
a=fig.add_subplot(212)
imgplot = plt.imshow(new_img)
a.set_title('Resized')

plt.show()
# Out:
# Original size: 400 x 400
# Scaled size: 128 x 128
# New size: 128 x 128

# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt
# %matplotlib inline

# We'll resize this so it's 200 x 200
target_size = (308,354)

# Show the original and resized images
# Create a figure
fig = plt.figure(figsize=(12, 12))



homedir = os.path.expanduser('~')
pathset = os.path.join(homedir, "notebooks/someImagesProcessed/")
print(pathset)

if not(os.path.exists(pathset)):
    print ("NEW DIRECTORY COOL")
    os.mkdir(pathset)

for imgData in someImages:
    orig_img = Image.fromarray(imgData[2])

    # Get the image size
    orig_height, orig_width = orig_img.size
    print('Original size:', orig_height, 'x', orig_width)

    # Subplot for original image
    #a=fig.add_subplot(211)
    #imgplot = plt.imshow(orig_img)
    #a.set_title('Original')

    # Scale the image to the new size using the thumbnail method
    scaled_img = orig_img
    scaled_img.thumbnail(target_size, Image.ANTIALIAS)
    scaled_height, scaled_width = scaled_img.size
    print('Scaled size:', scaled_height, 'x', scaled_width)

    # Create a new white image of the target size to be the background
    new_img = Image.new("RGB", target_size, (255, 255, 255))

    # paste the scaled image into the center of the white background image
    new_img.paste(scaled_img, (int((target_size[0] - scaled_img.size[0]) / 2), int((target_size[1] - scaled_img.size[1]) / 2)))
    new_height, new_width = new_img.size
    print('New size:', new_height, 'x', new_width)
    
    # save new image
    #output_filename = os.path.join(imgData[3], imgData[0])
    output_filename = imgData[0]
    print(output_filename)
    np.save(os.path.join(pathset, output_filename), np.array(new_img))


    # Subplot for resized image
    #a=fig.add_subplot(212)
    #imgplot = plt.imshow(new_img)
    #a.set_title('Resized')

    #plt.show()
# Out:
# /home/conductor/notebooks/someImagesProcessed/
# Original size: 400 x 400
# Scaled size: 308 x 308
# New size: 308 x 354
# PAAAAALKBOLDLPOPx1013041_zm.jpeg
# Original size: 400 x 400
# Scaled size: 308 x 308
# New size: 308 x 354
# PAAAAAJJDMJGLPOPx1013041_zm.jpeg
# Original size: 230 x 147
# Scaled size: 230 x 147
# New size: 308 x 354
# 894568.jpeg
# Original size: 230 x 151
# Scaled size: 230 x 151
# New size: 308 x 354
# 894457.jpeg
# Original size: 230 x 143
# Scaled size: 230 x 143
# New size: 308 x 354
# 894456.jpeg

# %%
pic = np.array(new_img)
pic
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %% [markdown]
# key, value = images.popitem()
# print(key)
# print(value)
# img1 = Image.open(key)
# plt.imshow(img1)
# type(img1)

# %%
from PIL import Image, ImageOps

# %%
totalWidth = 0; 
totalHeight = 0; 

counter = 0; 

for value in images:
    counter += 1
    height = images[value][0]
    width = images[value][1]
    totalWidth += width
    totalHeight += height 
    
print('Average Width:', totalWidth / counter)
print('Average Height:',totalHeight / counter)
# Out:
# Average Width: 308.8223374175306
# Average Height: 354.20405278039584

# %%
import numpy as np


pathAndNPArray = {}

for value in images:
    pathAndNPArray[value] = np.array(Image.open(value))

for value in pathAndNPArray:
    print (value, pathAndNPArray[value].shape, pathAndNPArray[value])
# Out:
# gear_images/gear_images/gloves/41s18e0uSbL._AC_US320_QL65_.jpg (320, 320, 3) [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# gear_images/gear_images/axes/10189971_zm.jpeg (400, 400, 3) [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
# ...

# %%
iterator = iter(pathAndNPArray.items())
someImages = {}
i = 0; 
for k, v in pathAndNPArray.items():
    someImages[k] = v
    i += 1 
    if(i == 3):
        break

# %%
path, imageArray = someImages.popitem()
pwd = %pwd

np.save(pwd + '/data/' + path, imageArray)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-68196c223231> in <module>()
#       2 pwd = get_ipython().run_line_magic('pwd', '')
#       3
# ----> 4 np.save(pwd + '/data/' + path, imageArray)
#
# /anaconda/envs/py35/lib/python3.5/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     490         if not file.endswith('.npy'):
#     491             file = file + '.npy'
# --> 492         fid = open(file, "wb")
#     493         own_fid = True
#     494     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/conductor/notebooks/data/gear_images/gear_images/gloves/41s18e0uSbL._AC_US320_QL65_.jpg.npy'

# %%
path, imageArray = someImages

# %%
for path, imageArray in someImages.items():
    print(path, imageArray[0])
# Out:
# gear_images/gear_images/gloves/41s18e0uSbL._AC_US320_QL65_.jpg [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
# ...

# %%
from PIL import Image, ImageOps
import numpy as np
from tempfile import TemporaryFile

outfile = TemporaryFile()

target_size = (354, 308)

path, npArray = pathAndNPArray.popitem()

# %%
# So we wanna scale these to 350 by 300 to get a good middle ground for all the photos.

# %%
from PIL import Image, ImageOps
import numpy as np 

target_size = (354, 308)

for value in pathAndNPArray:
    img3 = np.load(pathAndNPArray[value])
    orig_img = Image.fromarray(img3)
    svaled_img = orig_img
    scaled_img.thumbnail(targe_size, Image.ANTIALIAS)
    scaled_height, scaled_width = scaled_img.size 
    print('Scaled size:', scaled_height, 'x', scaled_width)
    new_img = Image.new("RGB", target_size, (255, 255, 255))
    new_img.paste(scaled_img, (int((target_size[0] - scaled_img.size[0]) / 2), int((target_size[1] - scaled_img.size[1]) / 2)))
    new_height, new_width = new_img.size
    print('New Size: ', new_height, 'x', new_width)
